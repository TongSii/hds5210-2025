# %% [markdown]
# <a href="https://colab.research.google.com/github/TongSii/hds5210-2025/blob/main/week11/module31_filter_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**single-value-filter**

# %%
import pandas as pd

# %%
data = pd.read_csv('complications.csv')

# %%
data['city'].value_counts()
# Out:
# city
# BIRMINGHAM        76
# MONTGOMERY        38
# DOTHAN            38
# GADSDEN           38
# ANNISTON          38
# MOBILE            38
# LUVERNE           19
# ALABASTER         19
# FORT PAYNE        19
# SHEFFIELD         19
# OPP               19
# BOAZ              19
# FLORENCE          19
# OPELIKA           19
# CENTRE            19
# OZARK             19
# CULLMAN           19
# ANDALUSIA         19
# HUNTSVILLE        19
# HAMILTON          19
# TALLASSEE         19
# ENTERPRISE        19
# EUTAW             19
# DADEVILLE         19
# CENTREVILLE       19
# MOULTON           19
# SCOTTSBORO        19
# GENEVA            19
# FAYETTE           19
# ALEXANDER CITY    19
# EUFAULA           19
# ATHENS            19
# ASHLAND           19
# FOLEY             19
# DECATUR           19
# WINFIELD          19
# JASPER            19
# GROVE HILL        19
# TUSCALOOSA        19
# GREENSBORO        19
# WETUMPKA          19
# BREWTON           19
# FAIRHOPE          19
# ...

# %%
filter = data['city'] == 'DADEVILLE'

# %%
filter.value_counts()
# Out:
# city
# False    981
# True      19
# Name: count, dtype: int64

# %%
data_DADEVILLE = data[filter]

# %%
data_DADEVILLE.head()
# Out:
#      provider_id                   hospital_name             address  \
# 513        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 514        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 515        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 516        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 517        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
#
#           city state  zip_code county_name    phone_number     measure_id  \
# 513  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821  COMP_HIP_KNEE
# 514  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821    MORT_30_AMI
# 515  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821   MORT_30_CABG
# 516  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821   MORT_30_COPD
# 517  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821     MORT_30_HF
#
#                                           measure_name  \
# ...

# %%
data_DADEVILLE['state'].unique()
# Out:
# array(['AL'], dtype=object)

# %%
data_DADEVILLE['city'].unique()
# Out:
# array(['DADEVILLE'], dtype=object)

# %%
data_DADEVILLE.shape
# Out:
# (19, 18)

# %%
data_no = data[~filter]

# %%
len(data_no)
# Out:
# 981

# %%
data_no.shape
# Out:
# (981, 18)

# %% [markdown]
# # RegEx Filtering

# %%
med_center_filter = data['hospital_name'].str.contains('CENTER$')#all the hospital that name has  "CENTER",$:end
med_centers = data[med_center_filter]

# %%
med_centers.shape
# Out:
# (456, 18)

# %%
med_centers['hospital_name'].value_counts()
# Out:
# hospital_name
# SOUTHEAST ALABAMA MEDICAL CENTER              19
# NORTH ALABAMA MEDICAL CENTER                  19
# DEKALB REGIONAL MEDICAL CENTER                19
# SHELBY BAPTIST MEDICAL CENTER                 19
# DALE MEDICAL CENTER                           19
# FLOYD CHEROKEE MEDICAL CENTER                 19
# EAST ALABAMA MEDICAL CENTER                   19
# CULLMAN REGIONAL MEDICAL CENTER               19
# GADSDEN REGIONAL MEDICAL CENTER               19
# MARION REGIONAL MEDICAL CENTER                19
# FAYETTE MEDICAL CENTER                        19
# RIVERVIEW REGIONAL MEDICAL CENTER             19
# BIBB MEDICAL CENTER                           19
# LAWRENCE MEDICAL CENTER                       19
# HIGHLANDS MEDICAL CENTER                      19
# WIREGRASS MEDICAL CENTER                      19
# RUSSELL MEDICAL CENTER                        19
# NORTHEAST ALABAMA REGIONAL MEDICAL CENTER     19
# SOUTH BALDWIN REGIONAL MEDICAL CENTER         19
# ...

# %%
med_centers
# Out:
#      provider_id                     hospital_name                 address  \
# 0          10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1          10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2          10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3          10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4          10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ..           ...                               ...                     ...
# 983        10101   CITIZENS BAPTIST MEDICAL CENTER        604 STONE AVENUE
# 984        10101   CITIZENS BAPTIST MEDICAL CENTER        604 STONE AVENUE
# 985        10101   CITIZENS BAPTIST MEDICAL CENTER        604 STONE AVENUE
# 986        10101   CITIZENS BAPTIST MEDICAL CENTER        604 STONE AVENUE
# 987        10101   CITIZENS BAPTIST MEDICAL CENTER        604 STONE AVENUE
#
# ...

# %%
hospital_filter = data['hospital_name'].str.contains('HOSPITAL')
hospitals = data[hospital_filter]

# %%
hospitals.shape
# Out:
# (411, 18)

# %%
hospitals['hospital_name'].value_counts()
# Out:
# hospital_name
# MIZELL MEMORIAL HOSPITAL                  19
# CRENSHAW COMMUNITY HOSPITAL               19
# UAB CALLAHAN EYE HOSPITAL AUTHORITY       19
# HELEN KELLER MEMORIAL HOSPITAL            19
# JACKSON HOSPITAL & CLINIC INC             19
# UNIVERSITY OF ALABAMA HOSPITAL            19
# COMMUNITY HOSPITAL INC                    19
# STRINGFELLOW MEMORIAL HOSPITAL            19
# HUNTSVILLE HOSPITAL                       19
# GREENE COUNTY HOSPITAL                    19
# LAKE MARTIN COMMUNITY HOSPITAL            19
# FLOWERS HOSPITAL                          19
# CLAY COUNTY HOSPITAL                      19
# ATHENS LIMESTONE HOSPITAL                 19
# DECATUR MORGAN HOSPITAL-DECATUR CAMPUS    19
# PROVIDENCE HOSPITAL                       19
# GROVE HILL MEMORIAL HOSPITAL              19
# HALE COUNTY HOSPITAL                      19
# ELMORE COMMUNITY HOSPITAL                 19
# D W MCMILLAN MEMORIAL HOSPITAL            19
# ...

# %%
unknown = data[~hospital_filter & ~med_center_filter]

# %%
unknown['hospital_name'].unique()
# Out:
# array(['MARSHALL MEDICAL CENTERS SOUTH CAMPUS', "ST VINCENT'S EAST",
#        'BAPTIST MEDICAL CENTER SOUTH', 'ANDALUSIA HEALTH',
#        'MEDICAL CENTER ENTERPRISE', "ST VINCENT'S BIRMINGHAM",
#        'MEDICAL CENTER BARBOUR'], dtype=object)

# %%
data[~(hospital_filter | med_center_filter)]['hospital_name'].unique()
# Out:
# array(['MARSHALL MEDICAL CENTERS SOUTH CAMPUS', "ST VINCENT'S EAST",
#        'BAPTIST MEDICAL CENTER SOUTH', 'ANDALUSIA HEALTH',
#        'MEDICAL CENTER ENTERPRISE', "ST VINCENT'S BIRMINGHAM",
#        'MEDICAL CENTER BARBOUR'], dtype=object)

# %% [markdown]
# #**Complex filter**

# %%
data['compared_to_national'].value_counts()
# Out:
# compared_to_national
# No Different Than the National Rate     666
# Not Available                           143
# Number of Cases Too Small               114
# No Different Than the National Value     50
# Worse Than the National Rate             22
# Better Than the National Rate             3
# Worse Than the National Value             1
# Better Than the National Value            1
# Name: count, dtype: int64

# %% [markdown]
# # Multiple Filters
#
# Where the **Compared to National** is not `Number of Cases Too Small` and the Denominator is not `Not Available`, except we want all the mortality related measures regardless of those first two rules.

# %%
data['measure_id'].unique()
# Out:
# array(['COMP_HIP_KNEE', 'MORT_30_AMI', 'MORT_30_CABG', 'MORT_30_COPD',
#        'MORT_30_HF', 'MORT_30_PN', 'MORT_30_STK', 'PSI_10_POST_KIDNEY',
#        'PSI_11_POST_RESP', 'PSI_12_POSTOP_PULMEMB_DVT',
#        'PSI_13_POST_SEPSIS', 'PSI_14_POSTOP_DEHIS', 'PSI_15_ACC_LAC',
#        'PSI_3_ULCER', 'PSI_4_SURG_COMP', 'PSI_6_IAT_PTX',
#        'PSI_8_POST_HIP', 'PSI_90_SAFETY', 'PSI_9_POST_HEM'], dtype=object)

# %%
too_small = data['compared_to_national'] == 'Number of Cases Too Small'
not_avail = data['denominator'] == 'Not Available'
mortality = data['measure_id'].str.contains("^MORT")

# %%
data.shape
# Out:
# (1000, 18)

# %%
data[too_small].shape
# Out:
# (114, 18)

# %%
data[not_avail].shape
# Out:
# (309, 18)

# %%
data[mortality].shape
# Out:
# (318, 18)

# %%
subset = data[mortality | (~too_small & ~not_avail)]

# %%
subset.shape
# Out:
# (785, 18)

# %%
subset['measure_id'].value_counts()
# Out:
# measure_id
# MORT_30_AMI                  53
# MORT_30_CABG                 53
# MORT_30_STK                  53
# MORT_30_COPD                 53
# MORT_30_HF                   53
# MORT_30_PN                   53
# PSI_6_IAT_PTX                52
# PSI_8_POST_HIP               52
# PSI_3_ULCER                  52
# PSI_12_POSTOP_PULMEMB_DVT    41
# PSI_9_POST_HEM               41
# PSI_15_ACC_LAC               40
# PSI_14_POSTOP_DEHIS          39
# PSI_10_POST_KIDNEY           33
# PSI_13_POST_SEPSIS           32
# PSI_11_POST_RESP             32
# COMP_HIP_KNEE                30
# PSI_4_SURG_COMP              23
# Name: count, dtype: int64

# %%
subset['compared_to_national'].value_counts()
# Out:
# compared_to_national
# No Different Than the National Rate    666
# Number of Cases Too Small               54
# Not Available                           40
# Worse Than the National Rate            22
# Better Than the National Rate            3
# Name: count, dtype: int64

# %%
subset['denominator'].value_counts()
# Out:
# 29     5
# 85     4
# 73     3
# 79     3
# 113    3
#       ..
# 612    1
# 502    1
# 70     1
# 158    1
# 385    1
# Name: denominator, Length: 182, dtype: int64

# %%
subset.head()
# Out:
#    provider_id                     hospital_name                 address  \
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state  zip_code county_name    phone_number    measure_id  \
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_AMI
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701  MORT_30_CABG
# 3  DOTHAN    AL     36301     HOUSTON  (334) 793-8701  MORT_30_COPD
# 4  DOTHAN    AL     36301     HOUSTON  (334) 793-8701    MORT_30_HF
# 5  DOTHAN    AL     36301     HOUSTON  (334) 793-8701    MORT_30_PN
#
#                             measure_name                 compared_to_national  \
# ...

# %%
subset[mortality & too_small].head()
# Out:
# /tmp/ipython-input-355243577.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   subset[mortality & too_small].head()
#      provider_id                hospital_name              address     city  \
# 58         10007     MIZELL MEMORIAL HOSPITAL        702 N MAIN ST      OPP
# 77         10008  CRENSHAW COMMUNITY HOSPITAL  101 HOSPITAL CIRCLE  LUVERNE
# 82         10008  CRENSHAW COMMUNITY HOSPITAL  101 HOSPITAL CIRCLE  LUVERNE
# 191        10021          DALE MEDICAL CENTER     126 HOSPITAL AVE    OZARK
# 196        10021          DALE MEDICAL CENTER     126 HOSPITAL AVE    OZARK
#
#     state  zip_code county_name    phone_number   measure_id  \
# 58     AL     36467   COVINGTON  (334) 493-3541  MORT_30_AMI
# 77     AL     36049    CRENSHAW  (334) 335-3374  MORT_30_AMI
# 82     AL     36049    CRENSHAW  (334) 335-3374  MORT_30_STK
# 191    AL     36360        DALE  (334) 774-2601  MORT_30_AMI
# ...

# %%
subset[mortality & too_small].shape
# Out:
# /tmp/ipython-input-1630061749.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   subset[mortality & too_small].shape
# (54, 18)

# %%
data[data['city'] == 'DADEVILLE' | data['city'] == 'BIRMINGHAM']

# %%
birmingham = data['city'] == 'BIRMINGHAM'
dadeville = data['city'] == 'DADEVILLE'
data[birmingham | dadeville]

data[birmingham | dadeville]['city'].value_counts()
# Out:
# BIRMINGHAM    76
# DADEVILLE     19
# Name: city, dtype: int64

# %% [markdown]
# # DataFrame.query()

# %%
data.query('city in ("DADEVILLE", "BIRMINGHAM")')
# Out:
#      provider_id            hospital_name                     address  \
# 95         10011        ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 96         10011        ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 97         10011        ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 98         10011        ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# 99         10011        ST VINCENT'S EAST  50 MEDICAL PARK EAST DRIVE
# ..           ...                      ...                         ...
# 565        10056  ST VINCENT'S BIRMINGHAM      810 ST VINCENT'S DRIVE
# 566        10056  ST VINCENT'S BIRMINGHAM      810 ST VINCENT'S DRIVE
# 567        10056  ST VINCENT'S BIRMINGHAM      810 ST VINCENT'S DRIVE
# 568        10056  ST VINCENT'S BIRMINGHAM      810 ST VINCENT'S DRIVE
# 569        10056  ST VINCENT'S BIRMINGHAM      810 ST VINCENT'S DRIVE
#
#            city state  zip_code county_name    phone_number       measure_id  \
# ...

# %%
data.head()

# %%
data.query('city == "DADEVILLE" and state == "AL"').head()
# Out:
#      provider_id                   hospital_name             address  \
# 513        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 514        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 515        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 516        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
# 517        10052  LAKE MARTIN COMMUNITY HOSPITAL  201 MARIARDEN ROAD
#
#           city state  zip_code county_name    phone_number     measure_id  \
# 513  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821  COMP_HIP_KNEE
# 514  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821    MORT_30_AMI
# 515  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821   MORT_30_CABG
# 516  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821   MORT_30_COPD
# 517  DADEVILLE    AL     36853  TALLAPOOSA  (256) 825-7821     MORT_30_HF
#
#                                           measure_name  \
# ...

# %% [markdown]
# # Generic Complex Filtering
#
# Apply some generic function to an entire row to figure out if should be filtered.

# %%
with_score = data[(data['score'] != 'Not Available') & (data['denominator'] != 'Not Available')]

# %%
mask = with_score.apply(lambda x: (float(x['score']) / float(x['denominator'])) > 0.10, axis=1)#row

# %%
with_score.shape
# Out:
# (691, 18)

# %%
with_score[mask].shape
# Out:
# (113, 18)

# %%
with_score[mask].head()
# Out:
#     provider_id                          hospital_name  \
# 14        10001       SOUTHEAST ALABAMA MEDICAL CENTER
# 20        10005  MARSHALL MEDICAL CENTERS SOUTH CAMPUS
# 33        10005  MARSHALL MEDICAL CENTERS SOUTH CAMPUS
# 52        10006           NORTH ALABAMA MEDICAL CENTER
# 61        10007               MIZELL MEMORIAL HOSPITAL
#
#                        address      city state  zip_code county_name  \
# 14      1108 ROSS CLARK CIRCLE    DOTHAN    AL     36301     HOUSTON
# 20  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957    MARSHALL
# 33  2505 U S HIGHWAY 431 NORTH      BOAZ    AL     35957    MARSHALL
# 52         1701 VETERANS DRIVE  FLORENCE    AL     35630  LAUDERDALE
# 61               702 N MAIN ST       OPP    AL     36467   COVINGTON
#
#       phone_number       measure_id  \
# 14  (334) 793-8701  PSI_4_SURG_COMP
# 20  (256) 593-8310      MORT_30_AMI
# 33  (256) 593-8310  PSI_4_SURG_COMP
# 52  (256) 768-8400  PSI_4_SURG_COMP
# ...

# %% [markdown]
# #**PandasSQL**

# %%
# !pip install pandasql
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=5016844f046a43e03863339577378691575c7581fa8e5eb31a2c629d6f909a81
#   Stored in directory: /root/.cache/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# ...

# %%
import pandasql as ps

# %%
data = pd.read_csv('complications.csv')

# %%
data.head()
# Out:
#    provider_id                     hospital_name                 address  \
# 0        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4        10001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      city state  zip_code county_name    phone_number     measure_id  \
# 0  DOTHAN    AL     36301     HOUSTON  (334) 793-8701  COMP_HIP_KNEE
# 1  DOTHAN    AL     36301     HOUSTON  (334) 793-8701    MORT_30_AMI
# 2  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_CABG
# 3  DOTHAN    AL     36301     HOUSTON  (334) 793-8701   MORT_30_COPD
# 4  DOTHAN    AL     36301     HOUSTON  (334) 793-8701     MORT_30_HF
#
#                                         measure_name  \
# 0  Rate of complications for hip/knee replacement...
# ...

# %%
sql = """
select city, count(distinct [provider_id]) as providers
from data
where county_name='JEFFERSON'
group by city
"""

# %%
cities = ps.sqldf(sql, locals())

# %%
cities
# Out:
#          city  providers
# 0  BIRMINGHAM          4

# %%
data[data['county_name']=='JEFFERSON'].groupby(['city','provider_id']).count()
# Out:
#                         hospital_name  address  state  zip_code  county_name  \
# city       provider_id
# BIRMINGHAM 10011                   19       19     19        19           19
#            10018                   19       19     19        19           19
#            10033                   19       19     19        19           19
#            10056                   19       19     19        19           19
#
#                         phone_number  measure_id  measure_name  \
# city       provider_id
# BIRMINGHAM 10011                  19          19            19
#            10018                  19          19            19
#            10033                  19          19            19
#            10056                  19          19            19
#
#                         compared_to_national  denominator  score  \
# city       provider_id
# BIRMINGHAM 10011                          19           19     19
# ...

# %%
data[data['county_name']=='JEFFERSON'].groupby(['city','provider_id']).count().groupby(['city']).count()
# Out:
#             hospital_name  address  state  zip_code  county_name  \
# city
# BIRMINGHAM              4        4      4         4            4
#
#             phone_number  measure_id  measure_name  compared_to_national  \
# city
# BIRMINGHAM             4           4             4                     4
#
#             denominator  score  lower_estimate  higher_estimate  footnote  \
# city
# BIRMINGHAM            4      4               4                4         4
#
#             measure_start_date  measure_end_date
# city
# BIRMINGHAM                   4                 4

# %%
data[data['county_name']=='JEFFERSON'].groupby(['city','provider_id']).count().groupby(['city'])['hospital_name'].count()
# Out:
# city
# BIRMINGHAM    4
# Name: hospital_name, dtype: int64
